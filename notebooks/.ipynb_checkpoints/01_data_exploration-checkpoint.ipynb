# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

print("STEP 1: MYANMAR SENTIMENT DATA EXPLORATION (EDA)")
# Out:
# STEP 1: MYANMAR SENTIMENT DATA EXPLORATION (EDA)

# %%
df = pd.read_csv('../data/raw/myanmar_sentiment_full.csv')
print('File loaded!')
# Out:
# File loaded!

# %%
print("\n   First 5 rows:")
print(df.head())
# Out:
#    First 5 rows:
#                                                 Text  \
# 0   Enjoying a beautiful day at the park!        ...
# 1   Traffic was terrible this morning.           ...
# 2   Just finished an amazing workout! 💪          ...
# 3   Excited about the upcoming weekend getaway!  ...
# 4   Trying out a new recipe for dinner tonight.  ...
#
#                                              Text-MM    Sentiment  \
# 0  ပန်းခြံထဲမှာ လှပတဲ့နေ့လေးတစ်နေ့ကို ပျော်ရွှင်စ...   Positive
# 1                           ဒီမနက် လမ်းအရမ်းပိတ်တယ်   Negative
# 2  အရမ်းကောင်းတဲ့ လေ့ကျင့်ခန်းတစ်ခု ခုပဲပြီးသွားပ...   Positive
# 3  လာမယ့် စနေ၊ တနင်္ဂနွေ အပန်းဖြေခရီးအတွက် စိတ်လှ...   Positive
# 4  ဒီည ညစာအတွက် ဟင်းချက်နည်းအသစ်တစ်ခု စမ်းသပ်ချက်...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# 0   #Nature #Park                                  15.0   30.0     USA
# 1   #Traffic #Morning                               5.0   10.0     Canada
# 2   #Fitness #Workout                              20.0   40.0   USA
# 3   #Travel #Adventure                              8.0   15.0     UK
# 4   #Cooking #Food                                 12.0   25.0    Australia
#
#    Year  Month  Day  Hour
# 0  2023      1   15    12
# 1  2023      1   15     8
# 2  2023      1   15    15
# 3  2023      1   15    18
# 4  2023      1   15    19

# %%
print("\n🔍 4. MISSING VALUES CHECK...")
missing = df.isnull().sum()
missing_pct = (missing / len(df)) * 100
missing_df = pd.DataFrame({'Missing': missing, 'Percentage': missing_pct})
missing_df = missing_df[missing_df['Missing'] > 0]
if len(missing_df) > 0:
    print(missing_df)
else:
    print("   ✅ No missing values found!")
# Out:
# 🔍 4. MISSING VALUES CHECK...
#    ✅ No missing values found!

# %%
types = df['Sentiment'].nunique()
types
# Out:
# 279

# %%
sentiment_counts = df['Sentiment'].value_counts()
print(f"\n   Sentiment distribution (counts):")
for sent, count in sentiment_counts.items():
    pct = (count / len(df)) * 100
    bar = '█' * int(pct / 2)
    print(f"      {sent:15} {bar} {count:4} ({pct:5.1f}%)")
# Out:
#    Sentiment distribution (counts):
#        Positive       ███   44 (  6.0%)
#        Joy            ██   42 (  5.7%)
#        Excitement     ██   32 (  4.4%)
#        Contentment       14 (  1.9%)
#        Neutral           14 (  1.9%)
#        Happy             14 (  1.9%)
#        Hopeful            9 (  1.2%)
#        Gratitude          9 (  1.2%)
#        Sad                9 (  1.2%)
#        Curiosity          8 (  1.1%)
#        Embarrassed        8 (  1.1%)
#        Loneliness         7 (  1.0%)
#        Elation            6 (  0.8%)
#        Playful            6 (  0.8%)
#        Despair            6 (  0.8%)
#        Hate               6 (  0.8%)
#        Bad                6 (  0.8%)
#        Contentment        5 (  0.7%)
#        Serenity           5 (  0.7%)
#        Gratitude          5 (  0.7%)
#        Empowerment        5 (  0.7%)
#        Enthusiasm         5 (  0.7%)
#        Curiosity            5 (  0.7%)
#        Indifference         5 (  0.7%)
#        Confusion            5 (  0.7%)
#        Numbness             5 (  0.7%)
#        Melancholy           5 (  0.7%)
#        Nostalgia            5 (  0.7%)
#        Ambivalence          5 (  0.7%)
#        Acceptance           5 (  0.7%)
#        Determination        5 (  0.7%)
#        Serenity             5 (  0.7%)
#        Inspired           5 (  0.7%)
#        Bitterness         5 (  0.7%)
#        Frustrated         5 (  0.7%)
#        Negative           4 (  0.5%)
#        Neutral            4 (  0.5%)
#        Excitement         4 (  0.5%)
#        Euphoria           4 (  0.5%)
#        Hope               4 (  0.5%)
#        Tenderness         4 (  0.5%)
#        Arousal            4 (  0.5%)
#        Frustration        4 (  0.5%)
#        Proud              4 (  0.5%)
#        Grateful           4 (  0.5%)
#        Compassionate      4 (  0.5%)
#        Serenity           4 (  0.5%)
#        Inspiration        4 (  0.5%)
#        Nostalgia          4 (  0.5%)
#        Desolation         4 (  0.5%)
#        Grief              4 (  0.5%)
#        Betrayal           4 (  0.5%)
#        Awe                4 (  0.5%)
#        Acceptance         3 (  0.4%)
#        Bitter             3 (  0.4%)
#        Calmness           3 (  0.4%)
#        Kind               3 (  0.4%)
#        Pride              3 (  0.4%)
#        Compassion         3 (  0.4%)
#        Grief                3 (  0.4%)
#        Resentment           3 (  0.4%)
#        Boredom              3 (  0.4%)
#        Empathetic         3 (  0.4%)
#        Free-spirited      3 (  0.4%)
#        Confident          3 (  0.4%)
#        Fearful            3 (  0.4%)
#        Overwhelmed        3 (  0.4%)
#        Jealous            3 (  0.4%)
#        Devastated         3 (  0.4%)
#        Envious            3 (  0.4%)
#        Dismissive         3 (  0.4%)
#        Accomplishment      3 (  0.4%)
#        Adventure          3 (  0.4%)
#        Regret             3 (  0.4%)
#        Surprise           3 (  0.4%)
#        Pride              3 (  0.4%)
#        Anger              2 (  0.3%)
#        Fear               2 (  0.3%)
#        Sadness            2 (  0.3%)
#        Disgust            2 (  0.3%)
#        Happiness          2 (  0.3%)
#        Joy                2 (  0.3%)
#        postitive               2 (  0.3%)
#        Amusement          2 (  0.3%)
#        Enjoyment          2 (  0.3%)
#        Admiration         2 (  0.3%)
#        Affection          2 (  0.3%)
#        Awe                2 (  0.3%)
#        Disappointed       2 (  0.3%)
#        Surprise           2 (  0.3%)
#        Adoration          2 (  0.3%)
#        Anticipation       2 (  0.3%)
#        Confusion          2 (  0.3%)
#        Shame              2 (  0.3%)
#        Fulfillment        2 (  0.3%)
#        Reverence          2 (  0.3%)
#        Fulfillment        2 (  0.3%)
#        Reverence          2 (  0.3%)
#        Despair              2 (  0.3%)
#        Jealousy             2 (  0.3%)
#        Frustration          2 (  0.3%)
#        Envy                 2 (  0.3%)
#        Regret              2 (  0.3%)
#        Disgust              2 (  0.3%)
#        Zest               2 (  0.3%)
#        Yearning           2 (  0.3%)
#        Apprehensive       2 (  0.3%)
#        Determination      2 (  0.3%)
#        Contemplation      2 (  0.3%)
#        Reflection         2 (  0.3%)
#        Enchantment        2 (  0.3%)
#        Whimsy             2 (  0.3%)
#        Rejuvenation       2 (  0.3%)
#        Coziness           2 (  0.3%)
#        Gratitude          2 (  0.3%)
#        Awe                2 (  0.3%)
#        Grief              2 (  0.3%)
#        Despair            2 (  0.3%)
#        Isolation          2 (  0.3%)
#        Disappointment      2 (  0.3%)
#        Heartbreak         2 (  0.3%)
#        Loss               2 (  0.3%)
#        Happiness          2 (  0.3%)
#        Enthusiasm         2 (  0.3%)
#        Thrill             2 (  0.3%)
#        Reflection         2 (  0.3%)
#        Enchantment        2 (  0.3%)
#        Exploration        2 (  0.3%)
#        Captivation        2 (  0.3%)
#        Tranquility        2 (  0.3%)
#        Emotion            2 (  0.3%)
#        Creativity         2 (  0.3%)
#        Satisfaction       2 (  0.3%)
#        Mischievous        2 (  0.3%)
#        Confusion          1 (  0.1%)
#        Shame              1 (  0.1%)
#        Compassion         1 (  0.1%)
#        Elation            1 (  0.1%)
#        Loneliness           1 (  0.1%)
#        Anxiety              1 (  0.1%)
#        Intimidation         1 (  0.1%)
#        Helplessness         1 (  0.1%)
#        Despair            1 (  0.1%)
#        Anxiety            1 (  0.1%)
#        Intimidation       1 (  0.1%)
#        Helplessness       1 (  0.1%)
#        Jealousy           1 (  0.1%)
#        Numbness           1 (  0.1%)
#        Ambivalence        1 (  0.1%)
#        Awe                1 (  0.1%)
#        Nostalgia           1 (  0.1%)
#        Thrill             1 (  0.1%)
#        Calmness           1 (  0.1%)
#        Overwhelmed        1 (  0.1%)
#        Gratitude          1 (  0.1%)
#        Bittersweet        1 (  0.1%)
#        Curiosity          1 (  0.1%)
#        Admiration         1 (  0.1%)
#        Overjoyed          1 (  0.1%)
#        Inspiration        1 (  0.1%)
#        Motivation         1 (  0.1%)
#        Amusement          1 (  0.1%)
#        JoyfulReunion      1 (  0.1%)
#        Excitement         1 (  0.1%)
#        Satisfaction       1 (  0.1%)
#        Blessed            1 (  0.1%)
#        Anticipation       1 (  0.1%)
#        Nostalgia          1 (  0.1%)
#        Appreciation       1 (  0.1%)
#        Confidence         1 (  0.1%)
#        Surprise           1 (  0.1%)
#        Wonderment         1 (  0.1%)
#        Optimism           1 (  0.1%)
#        Pride              1 (  0.1%)
#        Happiness          1 (  0.1%)
#        Curiosity          1 (  0.1%)
#        Intrigue           1 (  0.1%)
#        PlayfulJoy         1 (  0.1%)
#        Mindfulness        1 (  0.1%)
#        DreamChaser        1 (  0.1%)
#        Elegance           1 (  0.1%)
#        Pensive            1 (  0.1%)
#        Thrill             1 (  0.1%)
#        Harmony            1 (  0.1%)
#        Creativity         1 (  0.1%)
#        Radiance           1 (  0.1%)
#        Wonder             1 (  0.1%)
#        Euphoria           1 (  0.1%)
#        Melodic            1 (  0.1%)
#        FestiveJoy         1 (  0.1%)
#        InnerJourney       1 (  0.1%)
#        Freedom            1 (  0.1%)
#        Dazzle             1 (  0.1%)
#        Adrenaline          1 (  0.1%)
#        Harmony            1 (  0.1%)
#        ArtisticBurst      1 (  0.1%)
#        Radiance           1 (  0.1%)
#        Wonder             1 (  0.1%)
#        Inspiration        1 (  0.1%)
#        CulinaryOdyssey      1 (  0.1%)
#        Euphoria           1 (  0.1%)
#        Curiosity          1 (  0.1%)
#        Resilience         1 (  0.1%)
#        Immersion          1 (  0.1%)
#        Spark              1 (  0.1%)
#        Gratitude          1 (  0.1%)
#        Marvel             1 (  0.1%)
#        Serenity           1 (  0.1%)
#        Heartbreak         1 (  0.1%)
#        Loneliness         1 (  0.1%)
#        Betrayal           1 (  0.1%)
#        Suffering          1 (  0.1%)
#        EmotionalStorm      1 (  0.1%)
#        Regret             1 (  0.1%)
#        Lostpostitive           1 (  0.1%)
#        Melancholy         1 (  0.1%)
#        Exhaustion         1 (  0.1%)
#        Sorrow             1 (  0.1%)
#        Darkness           1 (  0.1%)
#        Desperation        1 (  0.1%)
#        Ruins              1 (  0.1%)
#        Resilience         1 (  0.1%)
#        Sorrow             1 (  0.1%)
#        Heartache          1 (  0.1%)
#        Solitude           1 (  0.1%)
#        Positivity         1 (  0.1%)
#        Kindness           1 (  0.1%)
#        Friendship         1 (  0.1%)
#        postitive               1 (  0.1%)
#        Success            1 (  0.1%)
#        Amazement          1 (  0.1%)
#        Romance            1 (  0.1%)
#        Wonder             1 (  0.1%)
#        Grandeur           1 (  0.1%)
#        Energy             1 (  0.1%)
#        Celebration        1 (  0.1%)
#        Charm              1 (  0.1%)
#        Ecstasy            1 (  0.1%)
#        Hope               1 (  0.1%)
#        Colorful           1 (  0.1%)
#        Hypnotic           1 (  0.1%)
#        Connection         1 (  0.1%)
#        Iconic             1 (  0.1%)
#        Euphoria           1 (  0.1%)
#        Journey            1 (  0.1%)
#        Engagement         1 (  0.1%)
#        Touched            1 (  0.1%)
#        Suspense           1 (  0.1%)
#        Admiration         1 (  0.1%)
#        Triumph            1 (  0.1%)
#        Heartwarming       1 (  0.1%)
#        Obstacle           1 (  0.1%)
#        Sympathy           1 (  0.1%)
#        Pressure           1 (  0.1%)
#        Renewed Effort      1 (  0.1%)
#        Miscalculation      1 (  0.1%)
#        Challenge          1 (  0.1%)
#        Solace             1 (  0.1%)
#        Breakthrough       1 (  0.1%)
#        Harmony            1 (  0.1%)
#        Joy in Baking      1 (  0.1%)
#        Envisioning History      1 (  0.1%)
#        Imagination        1 (  0.1%)
#        Vibrancy           1 (  0.1%)
#        Mesmerizing        1 (  0.1%)
#        Culinary Adventure      1 (  0.1%)
#        Winter Magic       1 (  0.1%)
#        Thrilling Journey      1 (  0.1%)
#        Nature's Beauty      1 (  0.1%)
#        Celestial Wonder      1 (  0.1%)
#        Creative Inspiration      1 (  0.1%)
#        Runway Creativity      1 (  0.1%)
#        Ocean's Freedom      1 (  0.1%)
#        Whispers of the Past      1 (  0.1%)
#        Boredom            1 (  0.1%)
#        Indifference       1 (  0.1%)
#        Disgust            1 (  0.1%)
#        Relief             1 (  0.1%)
#        Positive           1 (  0.1%)

# %%
df['text_length_chars'] = df['Text-MM'].astype(str).str.len()
df['text_length_words'] = df['Text-MM'].astype(str).str.split().str.len()

# %%
print("\n🔤 8. ENCODING CHECK (Zawgyi vs Unicode)...")


def detect_zawgyi(text):
    """Simple heuristic to detect Zawgyi encoding"""
    if not isinstance(text, str):
        return False
    zawgyi_chars = ['ဥ', 'ဦ', 'ဧ', 'ဩ', 'ဪ']
    unicode_chars = ['ဉ', 'ည', 'ဋ', 'ဌ', 'ဍ']
    zawgyi_score = sum(1 for c in zawgyi_chars if c in text)
    unicode_score = sum(1 for c in unicode_chars if c in text)
    return zawgyi_score > unicode_score


df['is_zawgyi'] = df['Text-MM'].apply(detect_zawgyi)
zawgyi_count = df['is_zawgyi'].sum()
unicode_count = len(df) - zawgyi_count

print(f"\n   Zawgyi encoded: {zawgyi_count} ({zawgyi_count/len(df)*100:.1f}%)")
print(f"   Unicode encoded: {unicode_count} ({unicode_count/len(df)*100:.1f}%)")

if zawgyi_count > 0:
    print(f"\n   ⚠️  WARNING: Found {zawgyi_count} Zawgyi-encoded texts!")
    print(f"   These need conversion to Unicode before training.")
    print(f"\n   Sample Zawgyi text:")
    zawgyi_sample = df[df['is_zawgyi'] == True]['Text-MM'].iloc[0]
    print(f"      {zawgyi_sample[:100]}")
else:
    print(f"\n   ✅ All texts are in Unicode format!")
# Out:
# 🔤 8. ENCODING CHECK (Zawgyi vs Unicode)...
#
#    Zawgyi encoded: 6 (0.8%)
#    Unicode encoded: 726 (99.2%)
#
#    ⚠️  WARNING: Found 6 Zawgyi-encoded texts!
#    These need conversion to Unicode before training.
#
#    Sample Zawgyi text:
#       နွေဦးရာသီအတွက် ဥယျာဉ်ကို ပြုပြင်မွမ်းမံဖို့ စီစဉ်နေပါတယ်

# %%
print("\n. DUPLICATE CHECK...")

duplicates = df.duplicated(subset=['Text-MM']).sum()
print(f"\n   Exact duplicate texts: {duplicates} ({duplicates/len(df)*100:.1f}%)")

if duplicates > 0:
    print(f"   Found duplicate texts that may need removal.")
# Out:
# . DUPLICATE CHECK...
#
#    Exact duplicate texts: 28 (3.8%)
#    Found duplicate texts that may need removal.

# %%
if 'Platform' in df.columns:
    print("\n📱 10. PLATFORM DISTRIBUTION...")
    platform_counts = df['Platform'].value_counts()
    for platform, count in platform_counts.head(5).items():
        pct = (count / len(df)) * 100
        print(f"      {platform}: {count} ({pct:.1f}%)")
# Out:
# 📱 10. PLATFORM DISTRIBUTION...
#        Instagram : 258 (35.2%)
#        Facebook : 231 (31.6%)
#        Twitter : 128 (17.5%)
#        Twitter  : 115 (15.7%)
